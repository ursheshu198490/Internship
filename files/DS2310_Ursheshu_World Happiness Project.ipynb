# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing dataset
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.head(15)
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe               1
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# 5         Finland                   Western Europe               6
# 6     Netherlands                   Western Europe               7
# 7          Sweden                   Western Europe               8
# 8     New Zealand        Australia and New Zealand               9
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# 11     Costa Rica      Latin America and Caribbean              12
# 12        Austria                   Western Europe              13
# 13         Mexico      Latin America and Caribbean              14
# 14  United States                    North America              15
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0             7.587         0.03411                   1.39651  1.34951
# 1             7.561         0.04884                   1.30232  1.40223
# 2             7.527         0.03328                   1.32548  1.36058
# 3             7.522         0.03880                   1.45900  1.33095
# 4             7.427         0.03553                   1.32629  1.32261
# 5             7.406         0.03140                   1.29025  1.31826
# 6             7.378         0.02799                   1.32944  1.28017
# 7             7.364         0.03157                   1.33171  1.28907
# 8             7.286         0.03371                   1.25018  1.31967
# 9             7.284         0.04083                   1.33358  1.30923
# 10            7.278         0.03470                   1.22857  1.22393
# 11            7.226         0.04454                   0.95578  1.23788
# 12            7.200         0.03751                   1.33723  1.29704
# 13            7.187         0.04176                   1.02054  0.91451
# 14            7.119         0.03839                   1.39451  1.24711
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                    0.94143  0.66557                        0.41978
# 1                    0.94784  0.62877                        0.14145
# 2                    0.87464  0.64938                        0.48357
# 3                    0.88521  0.66973                        0.36503
# 4                    0.90563  0.63297                        0.32957
# 5                    0.88911  0.64169                        0.41372
# 6                    0.89284  0.61576                        0.31814
# 7                    0.91087  0.65980                        0.43844
# 8                    0.90837  0.63938                        0.42922
# 9                    0.93156  0.65124                        0.35637
# 10                   0.91387  0.41319                        0.07785
# 11                   0.86027  0.63376                        0.10583
# 12                   0.89042  0.62433                        0.18676
# 13                   0.81444  0.48181                        0.21312
# 14                   0.86179  0.54604                        0.15890
#
#     Generosity  Dystopia Residual
# 0      0.29678            2.51738
# 1      0.43630            2.70201
# 2      0.34139            2.49204
# 3      0.34699            2.46531
# 4      0.45811            2.45176
# 5      0.23351            2.61955
# 6      0.47610            2.46570
# 7      0.36262            2.37119
# 8      0.47501            2.26425
# 9      0.43562            2.26646
# 10     0.33172            3.08854
# 11     0.25497            3.17728
# 12     0.33088            2.53320
# 13     0.14074            3.60214
# 14     0.40105            2.51011

# %% [raw]
# Exploratory Data Analysis (EDA)

# %%
#Encoding categorical columns using OrdinalEncoder
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes == 'object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#Checking the columns of dataset
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
#Checking the types of column
df.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#Checking the null values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    float64
#  1   Region                         158 non-null    float64
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# dtypes: float64(11), int64(1)
# memory usage: 14.9 KB

# %%
#Lets visualize it using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#Checking number of unique values in each columns
df.nunique().to_frame('No of unique values')
# Out:
#                                No of unique values
# Country                                        158
# Region                                          10
# Happiness Rank                                 157
# Happiness Score                                157
# Standard Error                                 153
# Economy (GDP per Capita)                       158
# Family                                         158
# Health (Life Expectancy)                       157
# Freedom                                        158
# Trust (Government Corruption)                  157
# Generosity                                     158
# Dystopia Residual                              158

# %%
#Statistical Summary of new columns
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %% [raw]
# This give the statistical information of the numerical columns. The summary of the dataset looks perfect since there is no negative/invalid values present.
#
# From the above description we can observe the following:
#
# The counts of all the columns are same which means there are no missing values in the dataset.
#
# The mean value is greater than the median (50%) in Standard error, Trust, Generosity, Dystopia Residual columns which means the data is skewed to right in these column.
#
# The data in the column Happiness rank, Economy, Family, Health, Freedom, Generosity columns have mean value less than median the data is skewed to left.
#
# By summarizing the data we can observe there is a huge difference between 75% and max hence there are outliers present in the data.
#
# We can also notice the Standard Deviation, min, 25% percentile values from this describe method.

# %%
plt.figure(figsize = (22,10))
sns.heatmap(df.describe(),annot=True, fmt='0.2f', linewidth=0.2, linecolor='black', cmap='Spectral')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('Features Name', fontsize=14)
plt.title('Description Graph', fontsize=20)
plt.show()

# %%
#Lets see how data is distributed for every column

plt.figure(figsize=(20,15),facecolor = 'red')
plotnumber = 1

for column in df:
    if plotnumber<=13:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize = (20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.regplot(x='Happiness Score', y=i, data=df, color='r')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
    p+=1
    
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=17:
        plt.subplot(5,4,p)
        sns.scatterplot(x='Happiness Score', y=i, data=df, color='r')
        plt.xlabel('Happiness Score')
        plt.ylabel(i)
    p+=1
plt.show()

# %%
sns.pairplot(data=df, palette='Dark2')

# %%
#Lets check the outliers by plotting boxplot

plt.figure(figsize = (20,25))
p=1
for i in df:
    if p<=13:
        plt.subplot(5,4,p)
        sns.boxplot(df[i], palette = 'Set2_r')
        plt.xlabel(i)
        
    p+=1
plt.show()

# %% [raw]
# so we have found outliers in Standard Error, Trust, Generosity, Dystopia Residual column
#
# So removing the outliers using Zscore and IQR techniques before building the model and selected best one
#
# Formula of Z score = (Observed value - mean) / standard deviation

# %%
df.shape
# Out:
# (158, 12)

# %%
#Find the Interquartile range to find the outliers

#1st quarantile
q1 = df.quantile(0.25)

#3rd quarantile
q3 = df.quantile(0.75)

#IQR
iqr = q3-q1

# %%
q1
# Out:
# Country                          39.250000
# Region                            3.000000
# Happiness Rank                   40.250000
# Happiness Score                   4.526000
# Standard Error                    0.037268
# Economy (GDP per Capita)          0.545808
# Family                            0.856823
# Health (Life Expectancy)          0.439185
# Freedom                           0.328330
# Trust (Government Corruption)     0.061675
# Generosity                        0.150553
# Dystopia Residual                 1.759410
# Name: 0.25, dtype: float64

# %%
std_high = q3['Standard Error'] + (1.5 * iqr['Standard Error'])
print (std_high)

index = np.where(df['Standard Error']>std_high)

df=df.drop(df.index[index])
df.shape

print(df.shape)

df.reset_index()
# Out:
# 0.07484874999999999
# (148, 12)
#      index  Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        0    135.0     9.0               1            7.587         0.03411
# 1        1     58.0     9.0               2            7.561         0.04884
# 2        2     37.0     9.0               3            7.527         0.03328
# 3        3    105.0     9.0               4            7.522         0.03880
# 4        4     24.0     5.0               5            7.427         0.03553
# ..     ...      ...     ...             ...              ...             ...
# 143    152      0.0     7.0             153            3.575         0.03084
# 144    153    118.0     8.0             154            3.465         0.03464
# 145    154     13.0     8.0             155            3.340         0.03656
# 146    155    136.0     4.0             156            3.006         0.05015
# 147    157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 143                   0.31982  0.30285                   0.30335  0.23414
# 144                   0.22208  0.77370                   0.42864  0.59201
# 145                   0.28665  0.35386                   0.31910  0.48450
# 146                   0.66320  0.47489                   0.72193  0.15684
# 147                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 143                        0.09719     0.36510            1.95210
# 144                        0.55191     0.22628            0.67042
# 145                        0.08010     0.18260            1.63328
# 146                        0.18906     0.47179            0.32858
# 147                        0.10731     0.16681            1.56726
#
# [148 rows x 13 columns]

# %%
tr_high = q3['Trust (Government Corruption)'] + (1.5 * iqr['Trust (Government Corruption)'])
print (tr_high)

index = np.where(df['Trust (Government Corruption)']>tr_high)

df=df.drop(df.index[index])
df.shape

print(df.shape)

df.reset_index()
# Out:
# 0.35812499999999997
# (134, 12)
#      index  Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        1     58.0     9.0               2            7.561         0.04884
# 1        4     24.0     5.0               5            7.427         0.03553
# 2        6     99.0     9.0               7            7.378         0.02799
# 3        9      6.0     0.0              10            7.284         0.04083
# 4       10     64.0     4.0              11            7.278         0.03470
# ..     ...      ...     ...             ...              ...             ...
# 129    151     20.0     8.0             152            3.587         0.04324
# 130    152      0.0     7.0             153            3.575         0.03084
# 131    154     13.0     8.0             155            3.340         0.03656
# 132    155    136.0     4.0             156            3.006         0.05015
# 133    157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.30232  1.40223                   0.94784  0.62877
# 1                     1.32629  1.32261                   0.90563  0.63297
# 2                     1.32944  1.28017                   0.89284  0.61576
# 3                     1.33358  1.30923                   0.93156  0.65124
# 4                     1.22857  1.22393                   0.91387  0.41319
# ..                        ...      ...                       ...      ...
# 129                   0.25812  0.85188                   0.27125  0.39493
# 130                   0.31982  0.30285                   0.30335  0.23414
# 131                   0.28665  0.35386                   0.31910  0.48450
# 132                   0.66320  0.47489                   0.72193  0.15684
# 133                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.14145     0.43630            2.70201
# 1                          0.32957     0.45811            2.45176
# 2                          0.31814     0.47610            2.46570
# 3                          0.35637     0.43562            2.26646
# 4                          0.07785     0.33172            3.08854
# ..                             ...         ...                ...
# 129                        0.12832     0.21747            1.46494
# 130                        0.09719     0.36510            1.95210
# 131                        0.08010     0.18260            1.63328
# 132                        0.18906     0.47179            0.32858
# 133                        0.10731     0.16681            1.56726
#
# [134 rows x 13 columns]

# %%
plt.figure(figsize = (20,25), facecolor='green')
plotnumber = 1

for column in df:
    if plotnumber <=18:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column], color='b')
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.show()

# %%
#Checking for skewness
df.skew()
# Out:
# Country                          0.083024
# Region                          -0.028021
# Happiness Rank                  -0.032482
# Happiness Score                  0.129496
# Standard Error                   0.488702
# Economy (GDP per Capita)        -0.383642
# Family                          -1.012357
# Health (Life Expectancy)        -0.739617
# Freedom                         -0.408165
# Trust (Government Corruption)    1.053720
# Generosity                       1.116993
# Dystopia Residual               -0.044613
# dtype: float64

# %% [raw]
# Acceptable range of Skewness os -0.5 to 0.5
# The columns Trust and Generosity have Skewness in the data. Since TotalCharges has continuous data lets remove the skewness

# %%
#Removing Skewness using Cuberoot method
df['Trust (Government Corruption)'] = np.cbrt(df['Trust (Government Corruption)'])

# %%
#Removing Skewness using Cuberoot method
df['Generosity'] = np.cbrt(df['Generosity'])

# %%
#Checking for skewness again
df.skew()
# Out:
# Country                          0.083024
# Region                          -0.028021
# Happiness Rank                  -0.032482
# Happiness Score                  0.129496
# Standard Error                   0.488702
# Economy (GDP per Capita)        -0.383642
# Family                          -1.012357
# Health (Life Expectancy)        -0.739617
# Freedom                         -0.408165
# Trust (Government Corruption)   -0.423152
# Generosity                      -0.908395
# Dystopia Residual               -0.044613
# dtype: float64

# %%
#Checking the correlation between features and the target
cor = df.corr()
cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000 -0.009409       -0.033064
# Region                        -0.009409  1.000000        0.289693
# Happiness Rank                -0.033064  0.289693        1.000000
# Happiness Score                0.011381 -0.255718       -0.992159
# Standard Error                -0.000405 -0.061627        0.177047
# Economy (GDP per Capita)      -0.025770 -0.295996       -0.764232
# Family                         0.117138 -0.233848       -0.706443
# Health (Life Expectancy)       0.026777 -0.387698       -0.742438
# Freedom                        0.009319  0.090810       -0.488497
# Trust (Government Corruption)  0.004856  0.181166       -0.242564
# Generosity                     0.075931  0.274930       -0.066656
# Dystopia Residual             -0.051193 -0.133443       -0.569522
#
#                                Happiness Score  Standard Error  \
# Country                               0.011381       -0.000405
# Region                               -0.255718       -0.061627
# Happiness Rank                       -0.992159        0.177047
# Happiness Score                       1.000000       -0.186781
# Standard Error                       -0.186781        1.000000
# Economy (GDP per Capita)              0.756930       -0.151259
# Family                                0.716211       -0.132607
# Health (Life Expectancy)              0.726740       -0.216409
# Freedom                               0.494224       -0.119064
# Trust (Government Corruption)         0.255802       -0.042974
# Generosity                            0.085100       -0.041095
# Dystopia Residual                     0.583377       -0.041990
#
#                                Economy (GDP per Capita)    Family  \
# Country                                       -0.025770  0.117138
# Region                                        -0.295996 -0.233848
# Happiness Rank                                -0.764232 -0.706443
# Happiness Score                                0.756930  0.716211
# Standard Error                                -0.151259 -0.132607
# Economy (GDP per Capita)                       1.000000  0.646099
# Family                                         0.646099  1.000000
# Health (Life Expectancy)                       0.805910  0.540912
# Freedom                                        0.247568  0.394622
# Trust (Government Corruption)                  0.102480  0.105843
# Generosity                                    -0.154792 -0.009063
# Dystopia Residual                              0.073832  0.107249
#
#                                Health (Life Expectancy)   Freedom  \
# Country                                        0.026777  0.009319
# Region                                        -0.387698  0.090810
# Happiness Rank                                -0.742438 -0.488497
# Happiness Score                                0.726740  0.494224
# Standard Error                                -0.216409 -0.119064
# Economy (GDP per Capita)                       0.805910  0.247568
# Family                                         0.540912  0.394622
# Health (Life Expectancy)                       1.000000  0.264590
# Freedom                                        0.264590  1.000000
# Trust (Government Corruption)                  0.021969  0.368585
# Generosity                                    -0.014630  0.368980
# Dystopia Residual                              0.089131  0.092427
#
#                                Trust (Government Corruption)  Generosity  \
# Country                                             0.004856    0.075931
# Region                                              0.181166    0.274930
# Happiness Rank                                     -0.242564   -0.066656
# Happiness Score                                     0.255802    0.085100
# Standard Error                                     -0.042974   -0.041095
# Economy (GDP per Capita)                            0.102480   -0.154792
# Family                                              0.105843   -0.009063
# Health (Life Expectancy)                            0.021969   -0.014630
# Freedom                                             0.368585    0.368980
# Trust (Government Corruption)                       1.000000    0.228659
# Generosity                                          0.228659    1.000000
# Dystopia Residual                                   0.092511   -0.069993
#
#                                Dystopia Residual
# Country                                -0.051193
# Region                                 -0.133443
# Happiness Rank                         -0.569522
# Happiness Score                         0.583377
# Standard Error                         -0.041990
# Economy (GDP per Capita)                0.073832
# Family                                  0.107249
# Health (Life Expectancy)                0.089131
# Freedom                                 0.092427
# Trust (Government Corruption)           0.092511
# Generosity                             -0.069993
# Dystopia Residual                       1.000000

# %%
plt.figure (figsize = (26,14))
sns.heatmap(df.corr(),annot=True, fmt='0.2f', linewidth = 0.2, linecolor = 'black', cmap = 'Spectral')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('Features_name', fontsize=14)
plt.title('Descriptive Graph', fontsize = 20)
plt.show()

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992159
# Region                          -0.255718
# Standard Error                  -0.186781
# Country                          0.011381
# Generosity                       0.085100
# Trust (Government Corruption)    0.255802
# Freedom                          0.494224
# Dystopia Residual                0.583377
# Family                           0.716211
# Health (Life Expectancy)         0.726740
# Economy (GDP per Capita)         0.756930
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#Seperating Features and Label
x = df.drop(['Happiness Score'], axis=1)
y = df['Happiness Score']

# %%
#Feature Scaling using Standard Scalarization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)

# %%
x
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0   -0.384671  1.373842       -1.839067        0.338875
# 1   -1.117042  0.022687       -1.770771       -0.859019
# 2    0.498481  1.373842       -1.725240       -1.537615
# 3   -1.504768 -1.666257       -1.656944       -0.382021
# 4   -0.255430 -0.315101       -1.634179       -0.933718
# ..        ...       ...             ...             ...
# 129 -1.203203  1.036054        1.575737       -0.165122
# 130 -1.634010  0.698265        1.598502       -1.281116
# 131 -1.353986  1.036054        1.644033       -0.766319
# 132  1.295473 -0.315101        1.666798        0.456774
# 133  1.403175  1.036054        1.712329        1.997566
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.281367  1.549793                  1.361302  1.482524
# 1                    1.346219  1.255879                  1.181344  1.511429
# 2                    1.354742  1.099214                  1.126815  1.392986
# 3                    1.365943  1.206487                  1.291894  1.637168
# 4                    1.081830  0.891606                  1.216474 -0.001154
# ..                        ...       ...                       ...       ...
# 129                 -1.543799 -0.481800                 -1.523275 -0.126824
# 130                 -1.376865 -2.508521                 -1.386420 -1.233423
# 131                 -1.466609 -2.320220                 -1.319271  0.489620
# 132                 -0.447823 -1.873443                  0.398156 -1.765422
# 133                 -1.677563 -3.109859                 -1.467084 -0.336045
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                         0.509167    1.338046           1.126394
# 1                         1.884802    1.436587           0.667544
# 2                         1.819310    1.515541           0.693104
# 3                         2.032635    1.334921           0.327785
# 4                        -0.253152    0.813266           1.835121
# ..                             ...         ...                ...
# 129                       0.374220    0.092948          -1.141854
# 130                       0.012546    0.991449          -0.248614
# 131                      -0.220124   -0.176773          -0.833191
# 132                       0.938008    1.496809          -3.225443
# 133                       0.137654   -0.310308          -0.954243
#
# [134 rows x 11 columns]

# %%
#Finding variance inflation factor in each column i.e. x.shape[1] (1/1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#     VIF values                       Features
# 0     1.092539                        Country
# 1     1.440455                         Region
# 2    67.678183                 Happiness Rank
# 3     1.085237                 Standard Error
# 4    12.449938       Economy (GDP per Capita)
# 5     5.319077                         Family
# 6     7.659987       Health (Life Expectancy)
# 7     3.086853                        Freedom
# 8     1.487721  Trust (Government Corruption)
# 9     2.038831                     Generosity
# 10   16.873264              Dystopia Residual

# %% [raw]
# Modelling
#
# Finding the best random state

# %%
#importing necessary libraries:
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRS = 0
for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .30, random_state=i)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Best accuracy is", maxAccu, "at random_state", maxRS)
# Out:
# Best accuracy is 0.9988041720379293 at random_state 40

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .30, random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_LR))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_LR))
print('Mean Squared Error:', mean_squared_error(y_test, pred_LR))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# R2_score:  0.9988041720379293
# R2_score on training Data: 99.68274798860321
# Mean Absolute Error: 0.028785551139373387
# Mean Squared Error: 0.0012290037738283642
# Root mean squared error: 0.03505715010990432

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('Actual', fontsize=14)
plt.ylabel('Predicted', fontsize=14)
plt.title('Linear Regression', fontsize=18)
plt.show()

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_RFR))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_RFR))
print('Mean Squared Error:', mean_squared_error(y_test, pred_RFR))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# R2_score:  0.9976943964488254
# R2_score on training Data: 99.90432427090644
# Mean Absolute Error: 0.033658292682926805
# Mean Squared Error: 0.002369567826829291
# Root mean squared error: 0.048678206898254694

# %%
knn = KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_knn))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_knn))
print('Mean Squared Error:', mean_squared_error(y_test, pred_knn))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# R2_score:  0.8893432325378564
# R2_score on training Data: 93.41103462290683
# Mean Absolute Error: 0.2699024390243904
# Mean Squared Error: 0.11372671414634151
# Root mean squared error: 0.3372339160676777

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_GBR))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_GBR))
print('Mean Squared Error:', mean_squared_error(y_test, pred_GBR))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# R2_score:  0.9976399556239185
# R2_score on training Data: 99.99993698971717
# Mean Absolute Error: 0.03414705948440013
# Mean Squared Error: 0.0024255190015660517
# Root mean squared error: 0.049249558389553624

# %%
lasso = Lasso()
lasso.fit(x_train,y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_lasso))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_lasso))
print('Mean Squared Error:', mean_squared_error(y_test, pred_lasso))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_score:  0.170378021608377
# R2_score on training Data: 19.149078721939684
# Mean Absolute Error: 0.7546847578254255
# Mean Squared Error: 0.8526381508328829
# Root mean squared error: 0.9233840754707019

# %%
rd = Ridge()
rd.fit(x_train,y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_rd))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_rd))
print('Mean Squared Error:', mean_squared_error(y_test, pred_rd))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_rd)))
# Out:
# R2_score:  0.998568439428526
# R2_score on training Data: 99.67046861997422
# Mean Absolute Error: 0.030879114036374222
# Mean Squared Error: 0.001471276304459982
# Root mean squared error: 0.038357219717544466

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_dtr))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_dtr))
print('Mean Squared Error:', mean_squared_error(y_test, pred_dtr))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_dtr)))
# Out:
# R2_score:  0.9888362757717654
# R2_score on training Data: 100.0
# Mean Absolute Error: 0.066170731707317
# Mean Squared Error: 0.011473439024390221
# Root mean squared error: 0.1071141401701485

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr = svr.predict(x_test)
pred_train = svr.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_svr))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_svr))
print('Mean Squared Error:', mean_squared_error(y_test, pred_svr))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_svr)))
# Out:
# R2_score:  0.9797519246072245
# R2_score on training Data: 98.39593931265436
# Mean Absolute Error: 0.1168291548574118
# Mean Squared Error: 0.020809817013636708
# Root mean squared error: 0.14425608137488244

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr = ExtraTreesRegressor()
etr.fit(x_train, y_train)
pred_ETR = etr.predict(x_test)
pred_train = etr.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_ETR))
print('R2_score on training Data:', r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:', mean_absolute_error(y_test, pred_ETR))
print('Mean Squared Error:', mean_squared_error(y_test, pred_ETR))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred_ETR)))
# Out:
# R2_score:  0.9985875701320361
# R2_score on training Data: 100.0
# Mean Absolute Error: 0.029149268292683408
# Mean Squared Error: 0.0014516148585366224
# Root mean squared error: 0.038100063760269774

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR, x, y, cv=5, scoring = 'r2')
print(score)
print(score.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_LR) - score.mean())*100)
# Out:
# [0.91662743 0.83101727 0.91605382 0.64400772 0.98182532]
# <built-in method mean of numpy.ndarray object at 0x000002B7F0AD5D70>
# Difference between R2 score and cross validation score is - 14.08978615011921

# %%
score1 = cross_val_score(RFR, x, y, cv=5, scoring = 'r2')
print(score1)
print(score1.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_RFR) - score1.mean())*100)
# Out:
# [-3.6130897  -3.53287044 -1.63319327 -0.87548088 -2.61268489]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69F8D0>
# Difference between R2 score and cross validation score is - 345.1158232006386

# %%
score2 = cross_val_score(knn, x, y, cv=5, scoring = 'r2')
print(score2)
print(score2.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_knn) - score2.mean())*100)
# Out:
# [-6.91126863 -4.75202965 -3.20215988 -7.85970627 -5.13869236]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69E610>
# Difference between R2 score and cross validation score is - 646.2114588971116

# %%
score3 = cross_val_score(GBR, x, y, cv=5, scoring = 'r2')
print(score3)
print(score3.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_GBR) - score3.mean())*100)
# Out:
# [-2.51622386 -0.66013162 -0.79944072 -0.25340124 -2.11498459]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69C1B0>
# Difference between R2 score and cross validation score is - 226.64763628123293

# %%
score4 = cross_val_score(lasso, x, y, cv=5, scoring = 'r2')
print(score4)
print(score4.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_lasso) - score4.mean())*100)
# Out:
# [-30.2882243  -13.34128941   0.08895792 -18.70906051 -27.11909292]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69E670>
# Difference between R2 score and cross validation score is - 1804.411986574054

# %%
score5 = cross_val_score(rd, x, y, cv=5, scoring = 'r2')
print(score5)
print(score5.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_rd) - score5.mean())*100)
# Out:
# [0.87359001 0.8296462  0.92801804 0.67986661 0.96854729]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69C930>
# Difference between R2 score and cross validation score is - 14.263480937462214

# %%
score6 = cross_val_score(svr, x, y, cv=5, scoring = 'r2')
print(score6)
print(score6.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_svr) - score6.mean())*100)
# Out:
# [-9.59283236 -0.60498016  0.76557982 -1.23975414 -6.05535873]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69CB70>
# Difference between R2 score and cross validation score is - 432.5221039401264

# %%
score7 = cross_val_score(etr, x, y, cv=5, scoring = 'r2')
print(score7)
print(score7.mean)
print('Difference between R2 score and cross validation score is -', (r2_score(y_test, pred_ETR) - score7.mean())*100)
# Out:
# [-2.86884999  0.71023196  0.75463187  0.93715817 -2.37419247]
# <built-in method mean of numpy.ndarray object at 0x000002B7ED69C330>
# Difference between R2 score and cross validation score is - 156.67916589144303

# %% [raw]
# From the difference of both R2 score and Cross Validation score computed on R2 score we can conclude that Ridge Regression and Linear Regression as our best fitting and best performing model

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'alpha': [1.0, .05, .4, 2], 'fit_intercept': [True, False],
        'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag', 'saga', 'lbfgs'],
        'positive':[False, True],
        'random_state': [1,4,10,20]
        
        }
gscv = GridSearchCV(Ridge(), param, cv=5)
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 20,
#  'solver': 'sag'}

# %%
Model = Ridge(alpha = 1, fit_intercept=True, positive=False, random_state=20, solver = 'sag')

# %%
Model.fit(x_train, y_train)
pred=Model.predict(x_test)
print('R2_score: ', r2_score(y_test, pred))
print('Mean Absolute Error:', mean_absolute_error(y_test, pred))
print('Mean Squared Error:', mean_squared_error(y_test, pred))
print('Root mean squared error:', np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2_score:  0.9985663892656638
# Mean Absolute Error: 0.030896764125208545
# Mean Squared Error: 0.0014733833449161458
# Root mean squared error: 0.038384675912610564

# %%
#Saving the model using .pk1
import joblib
joblib.dump(Model, "WorldHappinessProject.pk1")
# Out:
# ['WorldHappinessProject.pk1']

# %%
#Lets load the saved model and get the predictions
model = joblib.load('WorldHappinessProject.pk1')

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([5.18017353, 4.72069487, 5.13591991, 4.71059484, 5.02714644,
#        5.32322271, 4.02101853, 4.64538198, 6.67134228, 6.39369007,
#        7.25330527, 7.18725411, 5.86050819, 4.6233528 , 5.82970482,
#        4.22724506, 6.78835558, 4.30720113, 5.16726038, 3.988183  ,
#        4.79912167, 4.42364345, 5.92008365, 4.76914201, 5.58871008,
#        4.49403416, 5.25115173, 4.664488  , 5.80477423, 6.96259111,
#        3.95115315, 5.92784397, 6.37693938, 6.77908621, 5.24560939,
#        4.89413962, 7.24527474, 3.66787566, 6.88521576, 4.80199963,
#        6.18505389])

# %%
a = np.array(y_test)
df=pd.DataFrame()
df['Predicted'] = prediction
df['Original'] = a
df
# Out:
#     Predicted  Original
# 0    5.180174     5.140
# 1    4.720695     4.715
# 2    5.135920     5.102
# 3    4.710595     4.694
# 4    5.027146     5.007
# 5    5.323223     5.268
# 6    4.021019     3.995
# 7    4.645382     4.686
# 8    6.671342     6.670
# 9    6.393690     6.455
# 10   7.253305     7.378
# 11   7.187254     7.200
# 12   5.860508     5.824
# 13   4.623353     4.610
# 14   5.829705     5.791
# 15   4.227245     4.271
# 16   6.788356     6.786
# 17   4.307201     4.350
# 18   5.167260     5.129
# 19   3.988183     3.989
# 20   4.799122     4.788
# 21   4.423643     4.436
# 22   5.920084     5.889
# 23   4.769142     4.786
# 24   5.588710     5.589
# 25   4.494034     4.514
# 26   5.251152     5.212
# 27   4.664488     4.642
# 28   5.804774     5.770
# 29   6.962591     6.937
# 30   3.951153     3.931
# 31   5.927844     5.878
# 32   6.376939     6.411
# 33   6.779086     6.750
# 34   5.245609     5.192
# 35   4.894140     4.949
# 36   7.245275     7.278
# 37   3.667876     3.656
# 38   6.885216     6.940
# 39   4.802000     4.800
# 40   6.185054     6.130
