# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia. Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
#fetching url
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
name = driver.find_elements(By.XPATH, '//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[1]')

# %%
for n in name:
    print(n.text)
# Out:
# "Baby Shark Dance"[6]
# "Despacito"[9]
# "Johny Johny Yes Papa"[17]
# "Bath Song"[18]
# "Shape of You"[19]
# "See You Again"[22]
# "Wheels on the Bus"[27]
# "Phonics Song with Two Words"[28]
# "Uptown Funk"[29]
# "Learning Colors – Colorful Eggs on a Farm"[30]
# "Gangnam Style"[31]
# "Masha and the Bear – Recipe for Disaster"[36]
# "Dame Tu Cosita"[37]
# "Axel F"[38]
# "Sugar"[39]
# "Counting Stars"[40]
# "Roar"[41]
# "Baa Baa Black Sheep"[42]
# "Waka Waka (This Time for Africa)"[43]
# "Lakdi Ki Kathi"[44]
# "Sorry"[45]
# "Thinking Out Loud"[46]
# "Humpty the train on a fruits ride"[47]
# "Dark Horse"[48]
# "Perfect"[49]
# "Shree Hanuman Chalisa"[50]
# "Let Her Go"[51]
# "Faded"[52]
# "Girls Like You"[53]
# "Lean On"[54]

# %%
artist = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[2]')

# %%
for a in artist:
    print(a.text)
# Out:
# Pinkfong Baby Shark - Kids' Songs & Stories
# Luis Fonsi
# LooLoo Kids - Nursery Rhymes and Children's Songs
# Cocomelon - Nursery Rhymes
# Ed Sheeran
# Wiz Khalifa
# Cocomelon - Nursery Rhymes
# ChuChu TV Nursery Rhymes & Kids Songs
# Mark Ronson
# Miroshka TV
# Psy
# Get Movies
# Ultra Records
# Crazy Frog
# Maroon 5
# OneRepublic
# Katy Perry
# Cocomelon - Nursery Rhymes
# Shakira
# Jingle Toons
# Justin Bieber
# Ed Sheeran
# Kiddiestv Hindi - Nursery Rhymes & Kids Songs
# Katy Perry
# Ed Sheeran
# T-Series Bhakti Sagar
# Passenger
# Alan Walker
# Maroon 5
# Major Lazer Official

# %%
date = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[4]')

# %%
for d in date:
    print(d.text)
# Out:
# June 17, 2016
# January 12, 2017
# October 8, 2016
# May 2, 2018
# January 30, 2017
# April 6, 2015
# May 24, 2018
# March 6, 2014
# November 19, 2014
# February 27, 2018
# July 15, 2012
# January 31, 2012
# April 5, 2018
# June 16, 2009
# January 14, 2015
# May 31, 2013
# September 5, 2013
# June 25, 2018
# June 4, 2010
# June 14, 2018
# October 22, 2015
# October 7, 2014
# January 26, 2018
# February 20, 2014
# November 9, 2017
# May 10, 2011
# July 25, 2012
# December 3, 2015
# May 31, 2018
# March 22, 2015

# %%
views = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[3]')

# %%
for v in views:
    print(v.text)
# Out:
# 13.78
# 8.33
# 6.85
# 6.52
# 6.15
# 6.11
# 5.74
# 5.59
# 5.10
# 5.03
# 4.98
# 4.57
# 4.49
# 4.19
# 3.97
# 3.93
# 3.92
# 3.86
# 3.80
# 3.78
# 3.74
# 3.70
# 3.65
# 3.64
# 3.61
# 3.57
# 3.57
# 3.56
# 3.53
# 3.51

# %%
print(len(name),len(artist),len(date),len(views))
# Out:
# 30 30 30 30

# %%
results = []

for i in range(len(name)):
    temporary_data={'Name': name[i].text,
                   'Artist': artist[i].text,
                   'Upload date': date[i].text,
                   'Views': views[i].text}
    results.append(temporary_data)

# %%
df_data = pd.DataFrame(results)
df_data
# Out:
#                                                Name  \
# 0                             "Baby Shark Dance"[6]
# 1                                    "Despacito"[9]
# 2                        "Johny Johny Yes Papa"[17]
# 3                                   "Bath Song"[18]
# 4                                "Shape of You"[19]
# 5                               "See You Again"[22]
# 6                           "Wheels on the Bus"[27]
# 7                 "Phonics Song with Two Words"[28]
# 8                                 "Uptown Funk"[29]
# 9   "Learning Colors – Colorful Eggs on a Farm"[30]
# 10                              "Gangnam Style"[31]
# 11   "Masha and the Bear – Recipe for Disaster"[36]
# 12                             "Dame Tu Cosita"[37]
# 13                                     "Axel F"[38]
# 14                                      "Sugar"[39]
# 15                             "Counting Stars"[40]
# 16                                       "Roar"[41]
# ...

# %%
driver.close()

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Series
# B) Place
# C) Date
# D) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
#fetching url
driver.get('https://www.bcci.tv/.')

# %%
search = driver.find_element(By.XPATH,'/html/body/header/div[3]/div[2]/ul/div[1]/a[2]')
search.click()

# %%
series = driver.find_elements(By.CLASS_NAME, 'match-tournament-name ng-binding')

# %%
Series = []
Place = []
Date = []
Time = []

# %%
#Scraping series name from the given path
series_tags=driver.find_elements(By.XPATH, '//h5[@class="match-tournament-name ng-binding"]')
for i in series_tags:
    series=i.text
    Series.append(series)
    
#Scraping place from the given path
place_tags=driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]')
for i in place_tags:
    place=i.text
    Place.append(place)
    
    
#Scraping date from the given path
date_tags = driver.find_elements(By.XPATH, '//div[@class="match-dates ng-binding"]')
for i in date_tags:
    date=i.text
    Date.append(date)
    

#Scraping time from the given path
time_tags = driver.find_elements(By.XPATH, '//div[@class="match-time no-margin ng-binding"]')
for i in time_tags:
    time=i.text
    Time.append(time)

# %%
print(len(Series), len(place), len(date), len(time))
# Out:
# 9 32 16 11

# %%
Series
# Out:
# ['AUSTRALIA WOMEN TOUR OF INDIA 2023-24',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2023-24',
#  'INDIA TOUR OF SOUTH AFRICA 2023-24',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2023-24',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2023-24',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2023-24',
#  'AFGHANISTAN TOUR OF INDIA 2023-24',
#  'AFGHANISTAN TOUR OF INDIA 2023-24',
#  'AFGHANISTAN TOUR OF INDIA 2023-24']

# %%
Place
# Out:
# ['Wankhede Stadium, Mumbai',
#  'Wankhede Stadium, Mumbai',
#  'Newlands, Cape Town',
#  'DY Patil Stadium, NAVI MUMBAI',
#  'DY Patil Stadium, NAVI MUMBAI',
#  'DY Patil Stadium, NAVI MUMBAI',
#  'Punjab Cricket Association IS Bindra Stadium, Mohali',
#  'Holkar Cricket Stadium, Indore',
#  'M Chinnaswamy Stadium, Bengaluru']

# %%
Date
# Out:
# ['30 DECEMBER, 2023',
#  '2 JANUARY, 2024',
#  '3 JANUARY, 2024',
#  '5 JANUARY, 2024',
#  '7 JANUARY, 2024',
#  '9 JANUARY, 2024',
#  '11 JANUARY, 2024',
#  '14 JANUARY, 2024',
#  '17 JANUARY, 2024']

# %%
Time
# Out:
# ['1:30 PM IST',
#  '1:30 PM IST',
#  '1:30 PM IST',
#  '7:00 PM IST',
#  '7:00 PM IST',
#  '7:00 PM IST',
#  '7:00 PM IST',
#  '7:00 PM IST',
#  '7:00 PM IST']

# %%
import pandas as pd
df = pd.DataFrame({'Series': Series, 'Place': Place, 'Date': Date, 'Time': Time})
df
# Out:
#                                   Series  \
# 0  AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 1  AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 2     INDIA TOUR OF SOUTH AFRICA 2023-24
# 3  AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 4  AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 5  AUSTRALIA WOMEN TOUR OF INDIA 2023-24
# 6      AFGHANISTAN TOUR OF INDIA 2023-24
# 7      AFGHANISTAN TOUR OF INDIA 2023-24
# 8      AFGHANISTAN TOUR OF INDIA 2023-24
#
#                                                Place               Date  \
# 0                           Wankhede Stadium, Mumbai  30 DECEMBER, 2023
# 1                           Wankhede Stadium, Mumbai    2 JANUARY, 2024
# 2                                Newlands, Cape Town    3 JANUARY, 2024
# 3                      DY Patil Stadium, NAVI MUMBAI    5 JANUARY, 2024
# 4                      DY Patil Stadium, NAVI MUMBAI    7 JANUARY, 2024
# 5                      DY Patil Stadium, NAVI MUMBAI    9 JANUARY, 2024
# ...

# %%
driver.close()

# %% [markdown]
# # 3. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details: A) Rank
# B) State
# C) GSDP(18-19)- at current prices
# D) GSDP(19-20)- at current prices
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

#Importing Select
from selenium.webdriver.support.ui import Select

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
#fetching url
driver.get('https://statisticstimes.com/')

# %%
search_new = driver.find_element(By.XPATH,'//div[@class="dropdown"][2]/div/a[2]')

# %%
search_new.click()

# %%
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#Scraping Rank name from the given path
rank_tags=driver.find_elements(By.ID, '//table[@id="table_id"]/tbody/tr/td[1]')
for i in rank_tags:
    series=i.text
    Rank.append(rank)
    
#Scraping State from the given path
state_tags=driver.find_elements(By.ID,'//table[@id="table_id"]/tbody/tr/td[2]')
for i in state_tags:
    state=i.text
    State.append(state)
    
    
#Scraping GSDP from the given path
gsdp1_tags = driver.find_elements(By.ID, '//table[@id="table_id"]/tbody/tr/td[3]')
for i in gsdp1_tags:
    gsdp1=i.text
    GSDP_1.append(gsdp1)
    

#Scraping GSDP2 from the given path
gsdp2_tags = driver.find_elements(By.ID, '//table[@id="table_id"]/tbody/tr/td[4]')
for i in gsdp2_tags:
    gsdp2=i.text
    GSDP_2.append(gsdp2)
    
#Scraping share from the given path
share_tags = driver.find_elements(By.ID, '//table[@id="table_id"]/tbody/tr/td[5]')
for i in share:
    share=i.text
    Share.append(share)
    
#Scrapping GDP from the given path
gdp_tags = driver.find_elements(By.ID, '//table[@id="table_id"]/tbody/tr/td[6]')
for i in gdp:
    gdp=i.texr
    GDP.append(gdp)
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[58], line 2
#       1 #Scraping Rank name from the given path
# ----> 2 rank_tags=driver.find_elements(By.ID, '//table[@id="table_id"]/tbody/tr/td[1]')
#       3 for i in rank_tags:
#       4     series=i.text
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     767     value = f'[name="{value}"]'
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# ...

# %% [markdown]
# # 4 Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
#fetching url
driver.get('https://github.com/')

# %%
search = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button')

# %%
search.click()

# %%
Title = driver.find_elements(By.XPATH, '/html/body/div[1]/div[4]/main/div[3]/div/div[2]/article[1]/h2/a/span')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 Title = driver.find_elements(By.XPATH, '/html/body/div[1]/div[4]/main/div[3]/div/div[2]/article[1]/h2/a/span')
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     767     value = f'[name="{value}"]'
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %%
Description = driver.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 Description = driver.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]')
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:771, in WebDriver.find_elements(self, by, value)
#     767     value = f'[name="{value}"]'
#     769 # Return empty list if driver returns null
#     770 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 771 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %% [markdown]
# # 5 Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
#fetching url
driver.get('https://www.billboard.com/')

# %%
salary_filter=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button/svg")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 salary_filter=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[4]/div/div[1]/div[1]/button/svg")
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# ...

# %%
salary_filter.click()

# %%
chart=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/h3/button')

# %%
chart.click()

# %%
play=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div/div/ul/li[1]/ul/li[2]/a')

# %%
play.click()

# %%
song = driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li/h3')

# %%
for s in song:
    print(s.text)
# Out:
# All I Want For Christmas Is You
# Rockin' Around The Christmas Tree
# Jingle Bell Rock
# Last Christmas
# A Holly Jolly Christmas
# Lovin On Me
# It's The Most Wonderful Time Of The Year
# Let It Snow, Let It Snow, Let It Snow!
# Feliz Navidad
# Sleigh Ride
# The Christmas Song (Merry Christmas To You)
# Santa Tell Me
# Underneath The Tree
# It's Beginning To Look A Lot Like Christmas
# White Christmas
# Jingle Bells
# Christmas (Baby Please Come Home)
# Cruel Summer
# Greedy
# Snooze
# Paint The Town Red
# Here Comes Santa Claus (Right Down Santa Claus Lane)
# Deck The Halls
# It's Beginning To Look A Lot Like Christmas
# Blue Christmas
# Water
# Run Rudolph Run
# I Remember Everything
# Agora Hills
# Santa Baby
# Little Saint Nick
# Please Come Home For Christmas
# Last Night
# You're A Mean One, Mr. Grinch
# Santa Claus Is Comin' To Town
# Wonderful Christmastime
# Thinkin' Bout Me
# Rudolph The Red-Nosed Reindeer
# Everybody
# Is It Over Now? (Taylor's Version) [From The Vault]
# ...

# %%
artist = driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[1]/span')

# %%
for a in artist:
    print(a.text)
# Out:
# Mariah Carey
# Brenda Lee
# Bobby Helms
# Wham!
# Burl Ives
# Jack Harlow
# Andy Williams
# Dean Martin
# Jose Feliciano
# The Ronettes
# Nat "King" Cole
# Ariana Grande
# Kelly Clarkson
# Perry Como And The Fontane Sisters With Mitchell Ayres And His Orchestra
# Bing Crosby With Ken Darby Singers & John Scott Trotter & His Orchestra
# Frank Sinatra With Orchestra Conducted By Gordon Jenkins
# Darlene Love
# Taylor Swift
# Tate McRae
# SZA
# Doja Cat
# Gene Autry
# Nat King Cole
# Michael Buble
# Elvis Presley
# Tyla
# Chuck Berry
# Zach Bryan Featuring Kacey Musgraves
# Doja Cat
# Eartha Kitt With Henri Rene And His Orchestra
# The Beach Boys
# Eagles
# Morgan Wallen
# Thurl Ravenscroft
# Jackson 5
# Paul McCartney
# Morgan Wallen
# Gene Autry & The Pinafores
# Nicki Minaj Featuring Lil Uzi Vert
# Taylor Swift
# Teddy Swims
# Nicki Minaj
# Jonas Brothers
# Andy Williams
# Donny Hathaway
# Luke Combs
# Paul Russell
# John & Yoko/The Plastic Ono Band With The Harlem Community Choir
# ...

# %%
lwr = driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[4]')

# %%
for l in lwr:
    print(l.text)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 10
# 12
# 8
# 15
# 14
# 11
# 24
# 23
# 20
# 18
# 13
# 9
# 16
# 17
# 25
# 28
# 19
# 27
# 21
# 38
# 22
# 30
# 31
# 40
# 45
# 29
# 41
# 37
# 35
# 32
# 33
# 26
# 36
# 47
# 42
# 46
# 49
# -
# 39
# 43
# -
# 53
# 44
# 51
# 55
# 54
# 52
# 62
# 56
# 59
# 61
# 71
# 57
# 72
# 70
# 66
# 67
# 34
# 78
# 77
# 79
# 76
# 83
# -
# 85
# 96
# 64
# 81
# -
# 68
# 90
# 99
# 88
# -
# 86
# -
# -
# -
# 93
# 84
# -
# 91
# 94
# -
# 97
# -
# -
# -
# -
# 69
# 92
# -
# -

# %%
peak = driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[5]')

# %%
for p in peak:
    print(p.text)
# Out:
# 1
# 1
# 3
# 4
# 4
# 1
# 5
# 8
# 6
# 8
# 9
# 12
# 11
# 12
# 12
# 16
# 15
# 1
# 7
# 2
# 1
# 22
# 16
# 19
# 24
# 10
# 10
# 1
# 14
# 30
# 29
# 18
# 1
# 31
# 33
# 28
# 7
# 16
# 26
# 1
# 39
# 42
# 43
# 18
# 37
# 2
# 23
# 38
# 14
# 11
# 1
# 12
# 31
# 8
# 47
# 25
# 11
# 26
# 46
# 34
# 61
# 48
# 2
# 5
# 34
# 52
# 42
# 11
# 40
# 11
# 71
# 55
# 73
# 64
# 51
# 76
# 27
# 78
# 5
# 55
# 81
# 28
# 83
# 84
# 85
# 77
# 56
# 88
# 68
# 90
# 91
# 14
# 93
# 94
# 95
# 96
# 69
# 61
# 30
# 100

# %%
weeks = driver.find_elements(By.XPATH, '//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul/li[6]')

# %%
for w in weeks:
    print(w.text)
# Out:
# 64
# 57
# 55
# 37
# 38
# 6
# 38
# 30
# 31
# 27
# 43
# 23
# 26
# 22
# 34
# 13
# 21
# 33
# 14
# 54
# 20
# 19
# 12
# 19
# 12
# 12
# 21
# 17
# 13
# 8
# 7
# 14
# 47
# 11
# 10
# 12
# 42
# 26
# 2
# 8
# 19
# 2
# 6
# 18
# 4
# 39
# 14
# 5
# 23
# 11
# 11
# 22
# 12
# 17
# 8
# 19
# 6
# 13
# 15
# 5
# 6
# 14
# 11
# 10
# 2
# 14
# 11
# 15
# 7
# 5
# 1
# 27
# 8
# 2
# 13
# 1
# 4
# 5
# 7
# 11
# 1
# 19
# 1
# 1
# 1
# 9
# 7
# 1
# 12
# 3
# 1
# 17
# 1
# 1
# 4
# 1
# 2
# 12
# 13
# 1

# %%
results = []

for i in range(len(song)):
    temporary_data={'Song name': song[i].text,
                   'Artist name': artist[i].text,
                   'Last week rank': lwr[i].text,
                   'Peak rank': peak[i].text,
                   'Weeks on board': weeks[i].text}
    results.append(temporary_data)

# %%
df_data = pd.DataFrame(results)
df_data
# Out:
#                             Song name                             Artist name  \
# 0     All I Want For Christmas Is You                            Mariah Carey
# 1   Rockin' Around The Christmas Tree                              Brenda Lee
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                  Winter Wonderland                                   Chloe
# 96                  Run For The Hills                              Tate McRae
# 97                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 98                       Great Gatsby                                Rod Wave
# 99                   One Of The Girls     The Weeknd, JENNIE & Lily Rose Depp
#
# ...

# %%
driver.close()

# %% [markdown]
# # 6. Scrape the details of Highest selling novels.
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
#fetching url
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
name = driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[2]')

# %%
for n in name:
    print(n.text)
# Out:
# Da Vinci Code,The
# Harry Potter and the Deathly Hallows
# Harry Potter and the Philosopher's Stone
# Harry Potter and the Order of the Phoenix
# Fifty Shades of Grey
# Harry Potter and the Goblet of Fire
# Harry Potter and the Chamber of Secrets
# Harry Potter and the Prisoner of Azkaban
# Angels and Demons
# Harry Potter and the Half-blood Prince:Children's Edition
# Fifty Shades Darker
# Twilight
# Girl with the Dragon Tattoo,The:Millennium Trilogy
# Fifty Shades Freed
# Lost Symbol,The
# New Moon
# Deception Point
# Eclipse
# Lovely Bones,The
# Curious Incident of the Dog in the Night-time,The
# Digital Fortress
# Short History of Nearly Everything,A
# Girl Who Played with Fire,The:Millennium Trilogy
# Breaking Dawn
# Very Hungry Caterpillar,The:The Very Hungry Caterpillar
# Gruffalo,The
# Jamie's 30-Minute Meals
# Kite Runner,The
# One Day
# Thousand Splendid Suns,A
# Girl Who Kicked the Hornets' Nest,The:Millennium Trilogy
# Time Traveler's Wife,The
# Atonement
# ...

# %%
author = driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[3]')

# %%
for a in author:
    print(a.text)
# Out:
# Brown, Dan
# Rowling, J.K.
# Rowling, J.K.
# Rowling, J.K.
# James, E. L.
# Rowling, J.K.
# Rowling, J.K.
# Rowling, J.K.
# Brown, Dan
# Rowling, J.K.
# James, E. L.
# Meyer, Stephenie
# Larsson, Stieg
# James, E. L.
# Brown, Dan
# Meyer, Stephenie
# Brown, Dan
# Meyer, Stephenie
# Sebold, Alice
# Haddon, Mark
# Brown, Dan
# Bryson, Bill
# Larsson, Stieg
# Meyer, Stephenie
# Carle, Eric
# Donaldson, Julia
# Oliver, Jamie
# Hosseini, Khaled
# Nicholls, David
# Hosseini, Khaled
# Larsson, Stieg
# Niffenegger, Audrey
# McEwan, Ian
# Fielding, Helen
# Clarkson, Jeremy
# Bernieres, Louis de
# Kay, Peter
# Martel, Yann
# Stephenson, Pamela
# Pelzer, Dave
# Donaldson, Julia
# McCourt, Frank
# Faulks, Sebastian
# Pullman, Philip
# Mosse, Kate
# Rowling, J.K.
# Stockett, Kathryn
# Parsons, Tony
# Golden, Arthur
# McCall Smith, Alexander
# Hislop, Victoria
# Ahern, Cecelia
# McKeith, Gillian
# Zafon, Carlos Ruiz
# Rowling, J.K.
# Grisham, John
# Atkins, Robert C.
# Pullman, Philip
# ...

# %%
volumes = driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[4]')

# %%
for v in volumes:
    print(v.text)
# Out:
# 5,094,805
# 4,475,152
# 4,200,654
# 4,179,479
# 3,758,936
# 3,583,215
# 3,484,047
# 3,377,906
# 3,193,946
# 2,950,264
# 2,479,784
# 2,315,405
# 2,233,570
# 2,193,928
# 2,183,031
# 2,152,737
# 2,062,145
# 2,052,876
# 2,005,598
# 1,979,552
# 1,928,900
# 1,852,919
# 1,814,784
# 1,787,118
# 1,783,535
# 1,781,269
# 1,743,266
# 1,629,119
# 1,616,068
# 1,583,992
# 1,555,135
# 1,546,886
# 1,539,428
# 1,508,205
# 1,489,403
# 1,352,318
# 1,310,207
# 1,310,176
# 1,231,957
# 1,217,712
# 1,208,711
# 1,204,058
# 1,184,967
# 1,181,503
# 1,181,093
# 1,153,181
# 1,132,336
# 1,130,802
# 1,126,337
# 1,115,549
# 1,108,328
# 1,107,379
# 1,104,403
# 1,092,349
# 1,090,847
# 1,087,262
# 1,054,196
# 1,037,160
# 1,023,688
# 1,015,956
# 1,009,873
# 1,004,414
# 1,003,780
# 1,002,314
# 998,213
# 992,846
# 986,753
# 986,115
# 970,509
# 967,466
# 963,353
# 962,515
# 959,496
# 956,114
# 945,640
# 931,312
# 925,425
# 924,695
# 906,968
# 905,086
# 890,847
# 869,671
# 869,659
# 862,602
# 856,540
# 845,858
# 842,535
# ...

# %%
publisher = driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[5]')

# %%
for p in publisher:
    print(p.text)
# Out:
# Transworld
# Bloomsbury
# Bloomsbury
# Bloomsbury
# Random House
# Bloomsbury
# Bloomsbury
# Bloomsbury
# Transworld
# Bloomsbury
# Random House
# Little, Brown Book
# Quercus
# Random House
# Transworld
# Little, Brown Book
# Transworld
# Little, Brown Book
# Pan Macmillan
# Random House
# Transworld
# Transworld
# Quercus
# Little, Brown Book
# Penguin
# Pan Macmillan
# Penguin
# Bloomsbury
# Hodder & Stoughton
# Bloomsbury
# Quercus
# Random House
# Random House
# Pan Macmillan
# Penguin
# Random House
# Random House
# Canongate
# HarperCollins
# Orion
# Pan Macmillan
# HarperCollins
# Random House
# Scholastic Ltd.
# Orion
# Bloomsbury
# Penguin
# HarperCollins
# Random House
# Little, Brown Book
# Headline
# HarperCollins
# Penguin
# Orion
# Bloomsbury
# Random House
# Random House
# Scholastic Ltd.
# Profile Books Group
# Random House
# Transworld
# Random House Childrens Books G
# Hodder & Stoughton
# Scholastic Ltd.
# Random House
# HarperCollins
# Random House
# Penguin
# ...

# %%
genre = driver.find_elements(By.XPATH, '//table[@class="in-article sortable"]/tbody/tr/td[6]')

# %%
for g in genre:
    print(g.text)
# Out:
# Crime, Thriller & Adventure
# Children's Fiction
# Children's Fiction
# Children's Fiction
# Romance & Sagas
# Children's Fiction
# Children's Fiction
# Children's Fiction
# Crime, Thriller & Adventure
# Children's Fiction
# Romance & Sagas
# Young Adult Fiction
# Crime, Thriller & Adventure
# Romance & Sagas
# Crime, Thriller & Adventure
# Young Adult Fiction
# Crime, Thriller & Adventure
# Young Adult Fiction
# General & Literary Fiction
# General & Literary Fiction
# Crime, Thriller & Adventure
# Popular Science
# Crime, Thriller & Adventure
# Young Adult Fiction
# Picture Books
# Picture Books
# Food & Drink: General
# General & Literary Fiction
# General & Literary Fiction
# General & Literary Fiction
# Crime, Thriller & Adventure
# General & Literary Fiction
# General & Literary Fiction
# General & Literary Fiction
# Humour: Collections & General
# General & Literary Fiction
# Autobiography: General
# General & Literary Fiction
# Biography: The Arts
# Autobiography: General
# ...

# %%
results = []

for i in range(len(name)):
    temporary_data={'Book name': name[i].text,
                   'Author name': author[i].text,
                   'Volumes sold': volumes[i].text,
                   'Publisher': publisher[i].text,
                   'Genre': genre[i].text}
    results.append(temporary_data)

# %%
df_data = pd.DataFrame(results)
df_data
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# # 7. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
#fetching url
driver.get('https://www.imdb.com/')

# %%
name = driver.find_elements(By.XPATH, '//div[@class="ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-43986a27-9 gaoUku cli-title"]/a/h3')

# %%
for n in name:
    print(n.text)
# Out:
# Reacher
# Percy Jackson and the Olympians
# The Crown
# Fargo
# Doctor Who
# Rick and Morty
# Obliterated
# My Life with the Walter Boys
# Slow Horses
# Monarch: Legacy of Monsters
# The Gilded Age
# A Murder at the End of the World
# Game of Thrones
# Yu Yu Hakusho
# Jujutsu Kaisen
# The Boys
# Vigil
# True Detective
# Blue Eye Samurai
# For All Mankind
# Yellowstone
# Suits
# Lawmen: Bass Reeves
# Grey's Anatomy
# Breaking Bad
# Young Sheldon
# Dr. Death
# The Walking Dead
# The Bear
# Friends
# Yellowjackets
# The Fall of the House of Usher
# Archie
# The Santa Clauses
# The Office
# The Sopranos
# Shameless
# Attack on Titan
# Invincible
# What If...?
# The Rookie
# Supernatural
# Stranger Things
# The Double Life of My Billionaire Husband
# Black Mirror
# Ted Lasso
# Fellow Travelers
# Succession
# The Big Bang Theory
# Criminal Minds
# One Piece
# Peaky Blinders
# School Spirits
# The Last of Us
# House of the Dragon
# Carol & The End of the World
# South Park
# ...

# %%
year = driver.find_elements(By.XPATH, '//div[@class="sc-43986a27-7 dBkaPT cli-title-metadata"]/span[1]')

# %%
for y in year:
    print(y.text)
# Out:
# 2022–
# 2023–
# 2016–2023
# 2014–2024
# 2005–
# 2013–
# 2023
# 2023–
# 2022–
# 2023–
# 2022–
# 2023
# 2011–2019
# 2023–
# 2020–
# 2019–
# 2021–
# 2014–
# 2023
# 2019–
# 2018–
# 2011–2019
# 2023
# 2005–
# 2008–2013
# 2017–2024
# 2021–2023
# 2010–2022
# 2022–
# 1994–2004
# 2021–
# 2023
# 2023
# 2022–2023
# 2005–2013
# 1999–2007
# 2011–2021
# 2013–2023
# 2021–
# 2021–
# 2018–
# 2005–2020
# 2016–2025
# 2023–
# 2011–
# 2020–2023
# 2023
# 2018–2023
# 2007–2019
# 2005–
# 1999–
# 2013–2022
# 2023–
# 2023–
# 2022–
# 2023
# 1997–
# 2023
# 2011–
# 1997–
# 1999–
# 2024–
# 2023
# 2023–
# 2003–
# 2019–2023
# 2009–2023
# 2023–
# 2023
# 2013–2020
# 2015–2022
# 2009–2020
# 2023–
# 2004–2012
# 2021–2023
# 2001
# 2013–
# 2023–
# 2013–2021
# 2020–
# 2023–
# 2005–
# 2023–
# 2002–2008
# 2019–
# 2019–
# 2019–
# 2022–
# 2023
# 1993–2018
# 1989–1998
# 2021–2025
# 2022–
# 2023–
# 2005–2017
# 1999–
# 2023–
# 2022–
# 2001–2005
# 2021–

# %%
genre = driver.find_elements(By.XPATH, '//div[@class="sc-43986a27-7 dBkaPT cli-title-metadata"]/span[3]')

# %%
for g in genre:
    print(g.text)
# Out:
# TV-MA
# TV-PG
# TV-MA
# TV-MA
# TV-PG
# TV-MA
# TV-MA
# TV-14
# TV-MA
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-MA
# TV-14
# TV-MA
# TV-PG
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-MA
# TV-MA
# TV-14
# TV-PG
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-14
# TV-14
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-PG
# TV-14
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-14
# TV-MA
# TV-MA
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-PG
# TV-MA
# TV-14
# TV-14
# TV-MA
# TV-14
# TV-14
# TV-14
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-PG
# TV-MA
# TV-MA
# TV-MA
# TV-14
# TV-MA
# TV-14
# TV-14
# TV-MA
# TV-MA

# %%
time = driver.find_elements(By.XPATH, '//div[@class="sc-43986a27-7 dBkaPT cli-title-metadata"]/span[2]')

# %%
for t in time:
    print(t.text)
# Out:
# 17 eps
# 8 eps
# 60 eps
# 51 eps
# 196 eps
# 74 eps
# 8 eps
# 10 eps
# 24 eps
# 10 eps
# 18 eps
# 7 eps
# 73 eps
# 5 eps
# 47 eps
# 32 eps
# 12 eps
# 30 eps
# 9 eps
# 40 eps
# 53 eps
# 134 eps
# 8 eps
# 421 eps
# 62 eps
# 141 eps
# 16 eps
# 177 eps
# 19 eps
# 234 eps
# 20 eps
# 8 eps
# 4 eps
# 12 eps
# 188 eps
# 86 eps
# 134 eps
# 98 eps
# 17 eps
# 19 eps
# 100 eps
# 327 eps
# 42 eps
# 28 eps
# 34 eps
# 8 eps
# 39 eps
# 280 eps
# 335 eps
# 1099 eps
# 36 eps
# 9 eps
# 10 eps
# 20 eps
# 10 eps
# 330 eps
# 8 eps
# 129 eps
# 140 eps
# 540 eps
# 8 eps
# 8 eps
# 8 eps
# 458 eps
# 32 eps
# 144 eps
# 10 eps
# 4 eps
# 93 eps
# 63 eps
# 250 eps
# 10 eps
# 176 eps
# 12 eps
# 10 eps
# 44 eps
# 8 eps
# 153 eps
# 19 eps
# 11 eps
# 172 eps
# 20 eps
# 60 eps
# 19 eps
# 25 eps
# 31 eps
# 16 eps
# 6 eps
# 217 eps
# 173 eps
# 14 eps
# 30 eps
# 17 eps
# 245 eps
# 420 eps
# 9 eps
# 17 eps
# 63 eps
# 40 eps

# %%
ratings = driver.find_elements(By.XPATH, '//span[@class="ipc-rating-star ipc-rating-star--base ipc-rating-star--imdb sc-9ab53865-1 iXEijC ratingGroup--imdb-rating"]')

# %%
for r in ratings:
    print(r.text)
# Out:
# 8.1
#  (169K)
# 7.6
#  (8.8K)
# 8.6
#  (246K)
# 8.9
#  (401K)
# 8.6
#  (242K)
# 9.1
#  (585K)
# 6.7
#  (12K)
# 7.1
#  (5.9K)
# 8.0
#  (55K)
# 7.0
#  (16K)
# 8.0
#  (34K)
# 7.2
#  (13K)
# 9.2
#  (2.2M)
# 7.3
#  (5.2K)
# 8.6
#  (100K)
# 8.7
#  (616K)
# 7.4
#  (25K)
# 8.9
#  (619K)
# 8.8
#  (39K)
# 8.1
#  (60K)
# 8.7
#  (200K)
# 8.4
#  (463K)
# 7.6
#  (6.6K)
# 7.6
#  (334K)
# 9.5
#  (2.1M)
# 7.6
#  (89K)
# 7.6
#  (15K)
# 8.1
#  (1.1M)
# 8.6
#  (174K)
# 8.9
#  (1.1M)
# 7.8
#  (79K)
# 7.9
#  (90K)
# 7.1
#  (1.4K)
# 6.4
#  (11K)
# 9.0
#  (685K)
# 9.2
#  (452K)
# 8.5
#  (273K)
# 9.1
#  (483K)
# 8.7
#  (184K)
# 7.4
#  (136K)
# 8.0
#  (61K)
# 8.4
#  (474K)
# 8.7
#  (1.3M)
# 6.3
#  (1K)
# 8.7
#  (624K)
# 8.8
#  (325K)
# 8.1
#  (6K)
# 8.9
#  (250K)
# 8.2
#  (852K)
# 8.1
#  (214K)
# 8.9
#  (214K)
# 8.8
#  (624K)
# 7.6
#  (7.6K)
# 8.8
#  (480K)
# 8.5
#  (352K)
# 7.2
#  (1.6K)
# 8.7
#  (400K)
# 8.3
#  (22K)
# 8.0
#  (339K)
# 7.9
#  (38K)
# 8.1
#  (120K)
# 7.4
#  (41K)
# 7.4
#  (2.1K)
# 7.8
# ...

# %%
votes = driver.find_elements(By.XPATH, '//span[@class="ipc-rating-star--voteCount"]')

# %%
for v in votes:
    print(v.text)
# Out:
#  (169K)
#  (8.8K)
#  (246K)
#  (401K)
#  (242K)
#  (585K)
#  (12K)
#  (5.9K)
#  (55K)
#  (16K)
#  (34K)
#  (13K)
#  (2.2M)
#  (5.2K)
#  (100K)
#  (616K)
#  (25K)
#  (619K)
#  (39K)
#  (60K)
#  (200K)
#  (463K)
#  (6.6K)
#  (334K)
#  (2.1M)
#  (89K)
#  (15K)
#  (1.1M)
#  (174K)
#  (1.1M)
#  (79K)
#  (90K)
#  (1.4K)
#  (11K)
#  (685K)
#  (452K)
#  (273K)
#  (483K)
#  (184K)
#  (136K)
#  (61K)
#  (474K)
#  (1.3M)
#  (1K)
#  (624K)
#  (325K)
#  (6K)
#  (250K)
#  (852K)
#  (214K)
#  (214K)
#  (624K)
#  (7.6K)
#  (480K)
#  (352K)
#  (1.6K)
#  (400K)
#  (22K)
#  (339K)
#  (38K)
#  (120K)
#  (41K)
#  (2.1K)
#  (159K)
#  (340K)
#  (164K)
#  (3.3K)
#  (35K)
#  (570K)
#  (623K)
#  (470K)
#  (71K)
#  (498K)
#  (399K)
#  (510K)
#  (24K)
#  (3.2K)
#  (350K)
#  (30K)
#  (101K)
#  (246K)
#  (102K)
#  (368K)
#  (226K)
#  (559K)
#  (124K)
#  (12K)
#  (8.8K)
#  (244K)
#  (344K)
#  (191K)
#  (61K)
#  (2.3K)
#  (173K)
#  (359K)
#  (132K)
#  (72K)
#  (146K)
#  (147K)

# %%
print(len(name),len(year),len(genre),len(ratings),len(votes),len(time))
# Out:
# 100 100 98 99 99 99

# %%
results = []

for i in range(len(name)):
    temporary_data={'Name': name[i].text,
                   'Year span': year[i].text,
                   'Genre': genre[i].text,
                   'Run time': time[i].text,
                   'Ratings': ratings[i].text,
                   'Votes': votes[i].text}
    results.append(temporary_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 6
#       1 results = []
#       3 for i in range(len(name)):
#       4     temporary_data={'Name': name[i].text,
#       5                    'Year span': year[i].text,
# ----> 6                    'Genre': genre[i].text,
#       7                    'Run time': time[i].text,
#       8                    'Ratings': ratings[i].text,
#       9                    'Votes': votes[i].text}
#      10     results.append(temporary_data)
#
# IndexError: list index out of range

# %%
driver.close()

# %% [markdown]
# # 8 Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/ You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
# !pip install selenium

# %%
#Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import pandas as pd

#Importing selenium webdriver
from selenium import webdriver

#Importing required Exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
driver.maximize_window()

# %%
#fetching url
driver.get('https://archive.ics.uci.edu/')

# %%
search = driver.find_element(By.XPATH, '//a[@class="btn-primary btn"]')
search.click()

# %%
dataset = driver.find_elements(By.XPATH, '//div[@class="relative col-span-8 sm:col-span-7"]/h2/a')

# %%
for d in dataset:
    print(d.text)
# Out:
# Iris
# Dry Bean Dataset
# Rice (Cammeo and Osmancik)
# Heart Disease
# Adult
# Wine
# Breast Cancer Wisconsin (Diagnostic)
# Diabetes
# Wine Quality
# Car Evaluation

# %%
type = driver.find_elements(By.XPATH, '//div[@class="col-span-3 flex items-center gap-2"][2]/span')

# %%
for t in type:
    print(t.text)
# Out:
# Tabular
# Multivariate
# Multivariate
# Multivariate
# Multivariate
# Tabular
# Multivariate
# Multivariate, Time-Series
# Multivariate
# Multivariate

# %%
task = driver.find_elements(By.XPATH, '//div[@class="col-span-3 flex items-center gap-2"][1]/span')

# %%
for i in task:
    print(i.text)
# Out:
# Classification
# Classification
# Classification
# Classification
# Classification
# Classification
# Classification
# Classification
# Classification, Regression
# Classification

# %%
attribute = driver.find_elements(By.XPATH, '//div[@class="relative col-span-8 sm:col-span-7"]/p')

# %%
for a in attribute:
    print(a.text)
# Out:
# A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.
# Images of 13,611 grains of 7 different registered dry beans were taken with a high-resolution camera. A total of 16 features; 12 dimensions and 4 shape forms, were obtained from the grains.
# A total of 3810 rice grain's images were taken for the two species, processed and feature inferences were made. 7 morphological features were obtained for each grain of rice.
# 4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach
# Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset.
# Using chemical analysis to determine the origin of wines
# Diagnostic Wisconsin Breast Cancer Database.
# This diabetes dataset is from AIM '94
# ...

# %%
instances = driver.find_elements(By.XPATH, '//div[@class="col-span-3 flex items-center gap-2"][3]/span')

# %%
for i in instances:
    print(i.text)
# Out:
# 150 Instances
# 13.61K Instances
# 3.81K Instances
# 303 Instances
# 48.84K Instances
# 178 Instances
# 569 Instances
# 1 Instances
# 4.9K Instances
# 1.73K Instances

# %%
features = driver.find_elements(By.XPATH, '//div[@class="col-span-3 flex items-center gap-2"][4]/span')

# %%
for f in features:
    print(f.text)
# Out:
# 4 Features
# 16 Features
# 7 Features
# 13 Features
# 14 Features
# 13 Features
# 30 Features
# 20 Features
# 12 Features
# 6 Features

# %%
print(len(dataset),len(type),len(task),len(attribute),len(instances),len(features))
# Out:
# 10 10 10 10 10 10

# %%
results = []

for i in range(len(dataset)):
    temporary_data={'Dataset name': dataset[i].text,
                   'Data type': type[i].text,
                   'Task': task[i].text,
                   'Attribute type': attribute[i].text,
                   'No of instances': instances[i].text,
                   'Features': features[i].text}
    results.append(temporary_data)

# %%
df_data = pd.DataFrame(results)
df_data
# Out:
#                            Dataset name                  Data type  \
# 0                                  Iris                    Tabular
# 1                      Dry Bean Dataset               Multivariate
# 2            Rice (Cammeo and Osmancik)               Multivariate
# 3                         Heart Disease               Multivariate
# 4                                 Adult               Multivariate
# 5                                  Wine                    Tabular
# 6  Breast Cancer Wisconsin (Diagnostic)               Multivariate
# 7                              Diabetes  Multivariate, Time-Series
# 8                          Wine Quality               Multivariate
# 9                        Car Evaluation               Multivariate
#
#                          Task  \
# 0              Classification
# 1              Classification
# 2              Classification
# 3              Classification
# 4              Classification
# 5              Classification
# ...
