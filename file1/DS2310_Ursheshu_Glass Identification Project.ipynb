# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing dataset
df=pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv')
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
df.head(15)
# Out:
#      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0    2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1    3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2    4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3    5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4    6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1
# 5    7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17   0.0    0.00    1
# 6    8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24   0.0    0.00    1
# 7    9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30   0.0    0.00    1
# 8   10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40   0.0    0.11    1
# 9   11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09   0.0    0.24    1
# 10  12  1.51763  12.80  3.66  1.27  73.01  0.60  8.56   0.0    0.00    1
# 11  13  1.51589  12.88  3.43  1.40  73.28  0.69  8.05   0.0    0.24    1
# 12  14  1.51748  12.86  3.56  1.27  73.21  0.54  8.38   0.0    0.17    1
# 13  15  1.51763  12.61  3.59  1.31  73.29  0.58  8.50   0.0    0.00    1
# 14  16  1.51761  12.81  3.54  1.23  73.24  0.58  8.39   0.0    0.00    1

# %% [raw]
# Exploratory Data Analysis (EDA)

# %%
#Checking the dimension of dataset
df.shape
# Out:
# (213, 11)

# %%
#Checking the types of column
df.dtypes
# Out:
# 1            int64
# 1.52101    float64
# 13.64      float64
# 4.49       float64
# 1.10       float64
# 71.78      float64
# 0.06       float64
# 8.75       float64
# 0.00       float64
# 0.00.1     float64
# 1.1          int64
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %%
#Checking number of unique values in each column
df.nunique().to_frame('No. of unique values')
# Out:
#          No. of unique values
# 1                         213
# 1.52101                   177
# 13.64                     142
# 4.49                       93
# 1.10                      117
# 71.78                     132
# 0.06                       65
# 8.75                      143
# 0.00                       34
# 0.00.1                     32
# 1.1                         6

# %%
#Dropping CustomerID column
df.drop('1', axis=1, inplace=True)

# %%
df.head()
# Out:
#    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
#Stastical summary of new columns
df.describe()
# Out:
#           1.52101       13.64        4.49        1.10       71.78        0.06  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#              8.75        0.00      0.00.1         1.1
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.180000    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %% [raw]
# This give the statistical information of the numerical columns. The summary of the dataset looks perfect since there is no negative/invalid values present.
#
# From the above description we can observe the following:
#
# The counts of all the columns are same which means there are no missing values in the dataset.
#
# The mean value is greater than the median (50%) in 13.64, 1.10, 8.75, 0.00, 0.00.1 which means the data is skewed to right in these column.
#
# The data in the column 4.49, 71.78, 0.06, 0.00, 0.00.1 have mean value less than median the data is skewed to left.
#
# By summarizing the data we can observe there is a huge difference between 75% and max hence there are outliers present in the data.
#
# We can also notice the Standard Deviation, min, 25% percentile values from this describe method.

# %%
#Visualize the number of churned columns
ax = sns.countplot(x='1.1', data=df)
print(df['1.1'].value_counts())
# Out:
# 1.1
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: count, dtype: int64

# %%
#Lets check how the data has been distributed in remaining column
plt.figure(figsize = (10,6), facecolor = 'white')
plotnumber = 1
for col in df:
    if plotnumber<=4:
        ax = plt.subplot(2,2,plotnumber)
        sns.distplot(df[col], color = 'm')
        plt.xlabel(col, fontsize = 12)
        plt.yticks(rotation = 0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize = (22,10))
sns.heatmap(df.describe(),annot=True, fmt='0.2f', linewidth=0.2, linecolor='black', cmap='Spectral')
plt.xlabel('Figure', fontsize=14)
plt.ylabel('Features Name', fontsize=14)
plt.title('Description Graph', fontsize=20)
plt.show()

# %%
sns.pairplot(df, hue = '1.1', palette = 'Dark2')
plt.show()

# %%
#Lets check the Outliers by plotting boxplot

plt.figure(figsize = (10,6), facecolor = 'white')
plotnumber = 1
for col in df:
    if plotnumber<=4:
        ax = plt.subplot(2, 2, plotnumber)
        sns.boxplot(df[col], palette = "Set2_r")
        plt.xlabel(col, fontsize = 15)
        plt.yticks(rotation = 0, fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %%
df['1.52101'] = np.log(df['1.52101'])

df['13.64'] = np.log(df['13.64'])

df['1.10'] = np.log(df['1.10'])

# %%
#Lets see how data is distributed for every column
plt.figure(figsize=(20,25), facecolor='white')
plotnumber=1

for column in df:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()

# %%
df.skew()
# Out:
# 1.52101    1.627092
# 13.64      0.038571
# 4.49      -1.154323
# 1.10      -0.853734
# 71.78     -0.744546
# 0.06       6.549276
# 8.75       2.040591
# 0.00       3.406749
# 0.00.1     1.747173
# 1.1        1.108861
# dtype: float64

# %%
#Removing skewness
df['0.06'] = np.cbrt(df['0.06'])

# %%
df.skew()
# Out:
# 1.52101    1.627092
# 13.64      0.038571
# 4.49      -1.154323
# 1.10      -0.853734
# 71.78     -0.744546
# 0.06      -0.602542
# 8.75       2.040591
# 0.00       3.406749
# 0.00.1     1.747173
# 1.1        1.108861
# dtype: float64

# %%
#Visualizing the correlation matrix by plotting heatmap
plt.figure(figsize = (20,15))
sns.heatmap(df.corr(), linewidths = 0.1, fmt = '.1g', linecolor = 'black', annot = True, cmap = 'Blues_r')
plt.yticks(rotation = 0);
plt.show()

# %% [raw]
# This heatmap shows the correlation matrix by visualizing the data. We can observe the relation between feature to feature and feature to label.
#
# This heatmap contains both positive and negative correlation
# 1) There is no much positive correlation between the Target and features
# 2) There are columns have positive correlation with the label column 'Churn'
# 3) The label is negatively correlated with few columns.
# 4) Also the column 0.00 has very correlation with the label, we can drop it if necessary.
# 5) The column 1.52101 and 8.75 and many other columns have high correlation with each other.

# %%
#Checking the correlation between features and the target
cor = df.corr()
cor
# Out:
#           1.52101     13.64      4.49      1.10     71.78      0.06      8.75  \
# 1.52101  1.000000 -0.205779 -0.127543 -0.410332 -0.539855 -0.209240  0.812262
# 13.64   -0.205779  1.000000 -0.248192  0.033542 -0.076488 -0.522438 -0.294241
# 4.49    -0.127543 -0.248192  1.000000 -0.363785 -0.160359  0.450819 -0.444559
# 1.10    -0.410332  0.033542 -0.363785  1.000000  0.039234  0.148734 -0.274937
# 71.78   -0.539855 -0.076488 -0.160359  0.039234  1.000000 -0.177299 -0.210141
# 0.06    -0.209240 -0.522438  0.450819  0.148734 -0.177299  1.000000 -0.334760
# 8.75     0.812262 -0.294241 -0.444559 -0.274937 -0.210141 -0.334760  1.000000
# 0.00     0.000651  0.308440 -0.492149  0.403713 -0.104361 -0.260425 -0.113121
# 0.00.1   0.145647 -0.241388  0.086906 -0.039935 -0.097674  0.148232  0.124674
# 1.1     -0.161595  0.486762 -0.744004  0.493888  0.147767 -0.438043  0.000372
#
#              0.00    0.00.1       1.1
# 1.52101  0.000651  0.145647 -0.161595
# 13.64    0.308440 -0.241388  0.486762
# 4.49    -0.492149  0.086906 -0.744004
# 1.10     0.403713 -0.039935  0.493888
# 71.78   -0.104361 -0.097674  0.147767
# 0.06    -0.260425  0.148232 -0.438043
# 8.75    -0.113121  0.124674  0.000372
# 0.00     1.000000 -0.059729  0.574896
# 0.00.1  -0.059729  1.000000 -0.191090
# 1.1      0.574896 -0.191090  1.000000

# %%
cor['1.1'].sort_values(ascending = False)
# Out:
# 1.1        1.000000
# 0.00       0.574896
# 1.10       0.493888
# 13.64      0.486762
# 71.78      0.147767
# 8.75       0.000372
# 1.52101   -0.161595
# 0.00.1    -0.191090
# 0.06      -0.438043
# 4.49      -0.744004
# Name: 1.1, dtype: float64

# %%
#Seperate features and label
x = df.drop("1.1", axis=1)
y = df["1.1"]

# %%
#Feature Scaling using Standard Scalarization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#       1.52101     13.64      4.49      1.10     71.78      0.06      8.75  \
# 0   -0.244559  0.614611  0.642937  0.001305  0.097091  0.342041 -0.792599
# 1   -0.717500  0.181330  0.608144  0.339412  0.433777  0.184051 -0.827734
# 2   -0.228031 -0.213600  0.705564 -0.142434 -0.058303  0.481328 -0.518546
# 3   -0.307372 -0.138827  0.656854 -0.249963  0.550322  0.451717 -0.623951
# 4   -0.790300 -0.746719  0.649895  0.477170  0.407878  0.579815 -0.623951
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.700956  0.908944 -1.862164  2.042239 -0.058303 -0.720352  0.156046
# 209 -0.495857  1.794903 -1.862164  1.036725  0.524423 -2.020518 -0.392060
# 210  0.759376  1.163684 -1.862164  1.077426  0.990604 -2.020518 -0.363952
# 211 -0.608320  1.186648 -1.862164  0.967507  1.236644 -2.020518 -0.335844
# 212 -0.409872  1.013632 -1.862164  1.157046  0.912907 -2.020518 -0.237466
#
#          0.00    0.00.1
# 0   -0.353808 -0.588301
# 1   -0.353808 -0.588301
# 2   -0.353808 -0.588301
# 3   -0.353808 -0.588301
# 4   -0.353808  2.082200
# ..        ...       ...
# 208  1.778672 -0.588301
# 209  2.844912 -0.588301
# 210  2.945501 -0.588301
# 211  2.804676 -0.588301
# 212  3.005854 -0.588301
#
# [213 rows x 9 columns]

# %%
#Finding varience inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["Features"] = x.columns

# %%
vif
# Out:
#    VIF values Features
# 0    9.056727  1.52101
# 1    5.796266    13.64
# 2    8.825470     4.49
# 3    2.596108     1.10
# 4    3.834868    71.78
# 5    4.222689     0.06
# 6   19.255436     8.75
# 7    3.642062     0.00
# 8    1.084961   0.00.1

# %%
#Dropping 8.75 column
x.drop("8.75", axis=1, inplace=True)

# %%
#Again Finding varience inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif["Features"] = x.columns

# %%
vif
# Out:
#    VIF values Features
# 0    4.703898  1.52101
# 1    2.871038    13.64
# 2    2.429271     4.49
# 3    2.415269     1.10
# 4    3.378747    71.78
# 5    2.725205     0.06
# 6    1.601161     0.00
# 7    1.080959   0.00.1

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu = 0
maxRS = 0
for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 30, random_state=i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Best accuracy is", maxAccu, "at random_state", maxRS)
# Out:
# Best accuracy is 0.9666666666666667 at random_state 11

# %%
#Creating test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=30, random_state=maxRS)

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
#Write one function and call as many times to check accuracy score of different models

def metric_score(clf,x_train,x_test,y_train,y_test, train=True):
    if train:
        y_pred = clf.predict(x_train)
        
        print('\n=============Train result==========')
        
        print(f'Accuracy score:  {accuracy_score(y_train,y_pred)*100:.2f}%')
        
    elif train == False:
        pred = clf.predict(x_test)
        
        print('\n=============Test result===========')
        
        print(f'Accuracy score:  {accuracy_score(y_test,pred)*100:.2f}%')
        
        print('\n \n Test classification report \n', classification_report(y_test, pred, digits = 2)) #Model confidence/accuracy

# %%
#Initiate RandomForestClassifier and train
random_clf = RandomForestClassifier()

#Train the model
random_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#call the function and pass dataset to check train and test score
metric_score(random_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(random_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  100.00%
#
# =============Test result===========
# Accuracy score:  90.00%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.86      1.00      0.92        12
#            2       0.88      0.78      0.82         9
#            3       1.00      0.50      0.67         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.90        30
#    macro avg       0.96      0.88      0.90        30
# weighted avg       0.91      0.90      0.89        30

# %%
#Initiate Logistic regression and train
lr_clf = LogisticRegression()

#Train the model
lr_clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#call the function and pass dataset to check train and test score
metric_score(lr_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(lr_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  67.76%
#
# =============Test result===========
# Accuracy score:  63.33%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.80      0.67      0.73        12
#            2       0.43      0.67      0.52         9
#            3       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.63        30
#    macro avg       0.54      0.56      0.54        30
# weighted avg       0.62      0.63      0.61        30

# %%
#Initiate ExtraTressClassifier and train
etc_clf = ExtraTreesClassifier()

#Train the model
etc_clf.fit(x_train,y_train)
# Out:
# ExtraTreesClassifier()

# %%
#call the function and pass dataset to check train and test score
metric_score(etc_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(etc_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  100.00%
#
# =============Test result===========
# Accuracy score:  83.33%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.91      0.83      0.87        12
#            2       0.73      0.89      0.80         9
#            3       0.50      0.50      0.50         2
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.83        30
#    macro avg       0.86      0.79      0.81        30
# weighted avg       0.85      0.83      0.83        30

# %%
#Initiate SVC and train
svc_clf = SVC()

#Train the model
svc_clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
#call the function and pass dataset to check train and test score
metric_score(svc_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(svc_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  79.23%
#
# =============Test result===========
# Accuracy score:  80.00%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.85      0.92      0.88        12
#            2       0.64      0.78      0.70         9
#            3       0.00      0.00      0.00         2
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.80        30
#    macro avg       0.75      0.70      0.71        30
# weighted avg       0.76      0.80      0.77        30

# %%
#Initiate GradientBoostClassifier and train
gbt_clf = GradientBoostingClassifier()

#Train the model
gbt_clf.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
#call the function and pass dataset to check train and test score
metric_score(gbt_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(gbt_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  100.00%
#
# =============Test result===========
# Accuracy score:  83.33%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.79      0.92      0.85        12
#            2       0.88      0.78      0.82         9
#            3       0.50      0.50      0.50         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      0.50      0.67         2
#
#     accuracy                           0.83        30
#    macro avg       0.86      0.78      0.81        30
# weighted avg       0.84      0.83      0.83        30

# %%
#Initiate AdaBoostClassifier and train
ada_clf = AdaBoostClassifier()

#Train the model
ada_clf.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
#call the function and pass dataset to check train and test score
metric_score(ada_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(ada_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  44.81%
#
# =============Test result===========
# Accuracy score:  66.67%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.61      0.92      0.73        12
#            2       0.57      0.44      0.50         9
#            3       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.67        30
#    macro avg       0.53      0.56      0.54        30
# weighted avg       0.58      0.67      0.61        30

# %%
#Initiate BaggingClassifier and train
bgc_clf = BaggingClassifier()

#Train the model
bgc_clf.fit(x_train,y_train)
# Out:
# BaggingClassifier()

# %%
#call the function and pass dataset to check train and test score
metric_score(ada_clf,x_train,x_test,y_train,y_test,train=True) #This is for training score

metric_score(ada_clf,x_train,x_test,y_train,y_test,train=False) #This is for testing score
# Out:
# =============Train result==========
# Accuracy score:  44.81%
#
# =============Test result===========
# Accuracy score:  66.67%
#
#
#  Test classification report
#                precision    recall  f1-score   support
#
#            1       0.61      0.92      0.73        12
#            2       0.57      0.44      0.50         9
#            3       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         2
#
#     accuracy                           0.67        30
#    macro avg       0.53      0.56      0.54        30
# weighted avg       0.58      0.67      0.61        30

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'criterion' : ['gini', 'entropy'],
             'random_state' : [10, 50, 1000],
             'max_depth' : [0, 10, 20],
             'n_jobs' : [-2, -1, 1],
             'n_estimators': [50, 100, 200, 300]}

# %%
GCV = GridSearchCV(RandomForestClassifier(), parameters, cv=5)

# %%
GCV.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [0, 10, 20],
#                          'n_estimators': [50, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'n_estimators': 100,
#  'n_jobs': -2,
#  'random_state': 1000}

# %%
Final_model = RandomForestClassifier(criterion = 'entropy', max_depth = 20, n_estimators = 100, n_jobs = -2, random_state = 1000)
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 93.33333333333333

# %%
#Saving the model using .pk1
import joblib
joblib.dump(Final_model, "GlassIdentification.pk1")
# Out:
# ['GlassIdentification.pk1']

# %%
#Lets load the saved model and get the predictions
model = joblib.load('GlassIdentification.pk1')

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([2, 2, 2, 5, 6, 2, 1, 1, 6, 1, 1, 2, 2, 2, 1, 7, 1, 3, 1, 1, 2, 1,
#        1, 1, 7, 1, 2, 1, 6, 5], dtype=int64)

# %%
a = np.array(y_test)
df=pd.DataFrame()
df['Predicted'] = prediction
df['Original'] = a
df
# Out:
#     Predicted  Original
# 0           2         2
# 1           2         2
# 2           2         2
# 3           5         5
# 4           6         6
# 5           2         2
# 6           1         1
# 7           1         1
# 8           6         6
# 9           1         1
# 10          1         2
# 11          2         2
# 12          2         2
# 13          2         3
# 14          1         1
# 15          7         7
# 16          1         1
# 17          3         3
# 18          1         1
# 19          1         1
# 20          2         2
# 21          1         1
# 22          1         1
# 23          1         1
# 24          7         7
# 25          1         1
# 26          2         2
# 27          1         1
# 28          6         6
# 29          5         5
